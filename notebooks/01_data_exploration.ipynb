# %% [markdown]
# #Data Exploration
#
# This section explores the dataset to understand its structure, data types, and overall quality.
# The goal is to identify potential issues such as missing values, incorrect data types, and initial patterns in the data.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('CustomerChurnRaw.csv')

# %%
#Verifying the data available in the database
data.head()

# %%
# Inspecting dataset structure and data types
data.info()

# %%
#Reviewing summary statistics; 'SeniorCitizen' is not informative in this context, while 'tenure' and 'MonthlyCharges' are relevant
data.describe()

# %%
# Checking for missing values in each column
data.isnull().sum()
